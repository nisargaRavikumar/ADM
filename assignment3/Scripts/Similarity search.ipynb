# %%
# !pip3 install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\nisar\new folder\lib\site-packages (2.7.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\nisar\new folder\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\nisar\new folder\lib\site-packages (from tensorflow) (1.42.0)
# Requirement already satisfied: absl-py>=0.4.0 in c:\users\nisar\new folder\lib\site-packages (from tensorflow) (1.0.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\nisar\new folder\lib\site-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in c:\users\nisar\new folder\lib\site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\nisar\new folder\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=9.0.1 in c:\users\nisar\new folder\lib\site-packages (from tensorflow) (12.0.0)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in c:\users\nisar\new folder\lib\site-packages (from tensorflow) (2.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\nisar\new folder\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: tensorboard~=2.6 in c:\users\nisar\new folder\lib\site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\nisar\new folder\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\nisar\new folder\lib\site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\nisar\new folder\lib\site-packages (from tensorflow) (1.20.1)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in c:\users\nisar\new folder\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in c:\users\nisar\new folder\lib\site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\nisar\new folder\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in c:\users\nisar\new folder\lib\site-packages (from tensorflow) (0.22.0)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in c:\users\nisar\new folder\lib\site-packages (from tensorflow) (0.36.2)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\nisar\new folder\lib\site-packages (from tensorflow) (3.19.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\nisar\new folder\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\nisar\new folder\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\nisar\new folder\lib\site-packages (from tensorboard~=2.6->tensorflow) (1.0.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\nisar\new folder\lib\site-packages (from tensorboard~=2.6->tensorflow) (2.3.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\nisar\new folder\lib\site-packages (from tensorboard~=2.6->tensorflow) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\nisar\new folder\lib\site-packages (from tensorboard~=2.6->tensorflow) (3.3.6)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\nisar\new folder\lib\site-packages (from tensorboard~=2.6->tensorflow) (52.0.0.post20210125)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\nisar\new folder\lib\site-packages (from tensorboard~=2.6->tensorflow) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\nisar\new folder\lib\site-packages (from tensorboard~=2.6->tensorflow) (2.25.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\nisar\new folder\lib\site-packages (from tensorboard~=2.6->tensorflow) (1.8.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\nisar\new folder\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\nisar\new folder\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\nisar\new folder\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\nisar\new folder\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\nisar\new folder\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\nisar\new folder\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.6->tensorflow) (3.4.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\nisar\new folder\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nisar\new folder\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\nisar\new folder\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (3.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\nisar\new folder\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\nisar\new folder\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\nisar\new folder\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (3.1.1)

# %%
# !pip3 install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\nisar\new folder\lib\site-packages (4.5.4.60)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\nisar\new folder\lib\site-packages (from opencv-python) (1.20.1)

# %%
import glob
import cv2
import os

import tensorflow as tf
from tensorflow.keras.applications.vgg19 import preprocess_input
from tensorflow.keras.models import Model
import tensorflow.keras.optimizers
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.applications import VGG16, EfficientNetB0
print(tf.__version__)

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MultiLabelBinarizer, LabelEncoder

import numpy as np
import pandas as pd
from tqdm import tqdm
from sklearn import manifold

import matplotlib.pyplot as plt
plt.rcParams.update({'pdf.fonttype': 'truetype'})
from matplotlib import offsetbox
import matplotlib.colors as colors
import matplotlib.cm as cmx
# Out:
# 2.7.0

# %%
base_path = r'C:\Users\nisar\Downloads\img_highres_seg-003'
df = pd.read_csv(base_path + '\input.csv')
df = df[df['Label'].isin(['MEN_Denim', 'MEN_Jackets_Vests', 'MEN_Pants','MEN_Shirts_Polos','MEN_Shorts','MEN_Suiting',
                          'MEN_Sweaters','MEN_Sweatshirts_Hoodies','MEN_Tees_Tanks','WOMEN_Blouses_Shirts','WOMEN_Cardigans',
                          'WOMEN_Denim','WOMEN_Dresses','WOMEN_Graphic_Tees','WOMEN_Jackets_Coats','WOMEN_Pants',
                          'WOMEN_Leggings','WOMEN_Rompers_Jumpsuits','WOMEN_Skirts','WOMEN_Sweaters','WOMEN_Sweatshirts_Hoodies'
                          ,'WOMEN_Tees_Tanks','WOMEN_Shorts'])]
count=0
data, labels = [], []
for index, row in df.iterrows():
    image_path = f'{base_path}\input_Images\{row["ImageName"]}'
    label = row['Label']
    if index==10000:
        break
    count+=1
    print(count)
    try:
        image = tf.keras.preprocessing.image.load_img(image_path, color_mode='rgb', target_size= (224, 224))
        image = np.array(image)
        data.append(image)
        labels.append(label)
    except Exception:
        print(f'Failed to load {image_path}')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-e8b6d5c1bd69> in <module>
#       1 base_path = r'C:\Users\nisar\Downloads\img_highres_seg-003'
# ----> 2 df = pd.read_csv(base_path + '\input.csv')
#       3 df = df[df['Label'].isin(['MEN_Denim', 'MEN_Jackets_Vests', 'MEN_Pants','MEN_Shirts_Polos','MEN_Shorts','MEN_Suiting',
#       4                           'MEN_Sweaters','MEN_Sweatshirts_Hoodies','MEN_Tees_Tanks','WOMEN_Blouses_Shirts','WOMEN_Cardigans',
#       5                           'WOMEN_Denim','WOMEN_Dresses','WOMEN_Graphic_Tees','WOMEN_Jackets_Coats','WOMEN_Pants',
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\nisar\\Downloads\\img_highres_seg-003\\input.csv'

# %%
print(f'Loaded {len(data)} images') 

label_set = list(set(df['Label']))
print(f'Image classes {label_set}')
print(df[['Label', 'ImageName']].groupby(['Label']).agg(['count']))


#
# Data pre-processing
#
x = np.array(data)
y = np.array(labels)

# EfficientNet models expect their inputs to be float tensors 
# of pixels with values in the [0-255] range.
x = x.astype('float32') 

mlb = MultiLabelBinarizer()
mlb.fit([label_set])
y = mlb.transform(np.atleast_2d(y).T)
print(f'Label mapper classes {mlb.classes_}')


#
# Data split
#
# x - n_samples X height X width X channels
# y - n_samples X onehot_labels
train_test_ratio = 0.75
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=train_test_ratio)
print(f'x_train: {x_train.shape}, x_test: {x_test.shape}')
print(f'y_train: {y_train.shape}, y_test: {y_test.shape}')
# Out:
# Loaded 10000 images
# Image classes ['WOMEN_Dresses', 'WOMEN_Rompers_Jumpsuits', 'MEN_Sweaters', 'MEN_Shirts_Polos', 'MEN_Shorts', 'WOMEN_Sweaters', 'MEN_Jackets_Vests', 'WOMEN_Pants', 'MEN_Denim', 'MEN_Tees_Tanks', 'WOMEN_Cardigans', 'MEN_Pants', 'WOMEN_Leggings', 'WOMEN_Jackets_Coats', 'MEN_Suiting', 'WOMEN_Blouses_Shirts', 'WOMEN_Graphic_Tees', 'WOMEN_Sweatshirts_Hoodies', 'WOMEN_Tees_Tanks', 'WOMEN_Skirts', 'MEN_Sweatshirts_Hoodies', 'WOMEN_Denim']
#                           ImageName
#                               count
# Label
# MEN_Denim                       345
# MEN_Jackets_Vests               341
# MEN_Pants                       888
# MEN_Shirts_Polos                583
# MEN_Shorts                      839
# MEN_Suiting                      29
# MEN_Sweaters                    490
# MEN_Sweatshirts_Hoodies         637
# MEN_Tees_Tanks                 2297
# WOMEN_Blouses_Shirts           6794
# WOMEN_Cardigans                1277
# WOMEN_Denim                     377
# WOMEN_Dresses                  6121
# WOMEN_Graphic_Tees             1052
# WOMEN_Jackets_Coats            1665
# WOMEN_Leggings                  329
# WOMEN_Pants                    1723
# WOMEN_Rompers_Jumpsuits        1524
# WOMEN_Skirts                   1779
# WOMEN_Sweaters                 2681
# WOMEN_Sweatshirts_Hoodies       735
# WOMEN_Tees_Tanks               9866
# Label mapper classes ['MEN_Denim' 'MEN_Jackets_Vests' 'MEN_Pants' 'MEN_Shirts_Polos'
#  'MEN_Shorts' 'MEN_Suiting' 'MEN_Sweaters' 'MEN_Sweatshirts_Hoodies'
#  'MEN_Tees_Tanks' 'WOMEN_Blouses_Shirts' 'WOMEN_Cardigans' 'WOMEN_Denim'
#  'WOMEN_Dresses' 'WOMEN_Graphic_Tees' 'WOMEN_Jackets_Coats'
#  'WOMEN_Leggings' 'WOMEN_Pants' 'WOMEN_Rompers_Jumpsuits' 'WOMEN_Skirts'
#  'WOMEN_Sweaters' 'WOMEN_Sweatshirts_Hoodies' 'WOMEN_Tees_Tanks']
# x_train: (7500, 224, 224, 3), x_test: (2500, 224, 224, 3)
# y_train: (7500, 22), y_test: (2500, 22)

# %%
len(x_train)
# Out:
# 7500

# %%
#
# Visualize a data sample 
#
def decode_labels(y, mlb):
    labels = np.array(mlb.inverse_transform(np.atleast_2d(y)))[:, 0]
    return labels

n_col, n_row = 6, 4
offset = 20
f, ax = plt.subplots(n_row, n_col, figsize=(12, 8))
for i in range(n_row):
    for j in range(n_col):
        idx = offset + n_col*i + j
        ax[i, j].imshow(x_train[idx]/255)
        ax[i, j].set_axis_off()
        ax[i, j].set_title(decode_labels(y_train[idx], mlb)[0])
plt.tight_layout()

# %%
#
# Fine-tune a pretrained EfficientNet model   
#
model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
for layer in model.layers:
    layer.trainable = False
    
mapper = model.output
mapper = Flatten()(mapper) 
mapper = Dense(32, activation='relu', name='embeddigns')(mapper)
mapper = Dense(y_train.shape[1], activation='softmax')(mapper)
transfer_model = Model(inputs=model.input, outputs=mapper)

learning_rate= 0.001
transfer_model.compile(loss="categorical_crossentropy", optimizer = tf.keras.optimizers.Adam(learning_rate = learning_rate), metrics = ["accuracy"])
history = transfer_model.fit(x_train, y_train, batch_size = 4, epochs=25, validation_data=(x_test, y_test))
# Out:
# Epoch 1/25
# 1875/1875 [==============================] - 277s 146ms/step - loss: 1.1545 - accuracy: 0.6735 - val_loss: 0.8543 - val_accuracy: 0.7316
# Epoch 2/25
# 1875/1875 [==============================] - 275s 147ms/step - loss: 0.7721 - accuracy: 0.7367 - val_loss: 0.8403 - val_accuracy: 0.7168
# Epoch 3/25
# 1875/1875 [==============================] - 276s 147ms/step - loss: 0.6949 - accuracy: 0.7636 - val_loss: 0.6577 - val_accuracy: 0.7700
# Epoch 4/25
# 1875/1875 [==============================] - 275s 147ms/step - loss: 0.6152 - accuracy: 0.7851 - val_loss: 0.8072 - val_accuracy: 0.7472
# Epoch 5/25
# 1875/1875 [==============================] - 280s 150ms/step - loss: 0.5496 - accuracy: 0.7992 - val_loss: 0.6821 - val_accuracy: 0.7820
# Epoch 6/25
# 1875/1875 [==============================] - 281s 150ms/step - loss: 0.4831 - accuracy: 0.8224 - val_loss: 0.6954 - val_accuracy: 0.7956
# Epoch 7/25
# 1875/1875 [==============================] - 278s 148ms/step - loss: 0.4599 - accuracy: 0.8396 - val_loss: 0.8569 - val_accuracy: 0.7940
# Epoch 8/25
# 1875/1875 [==============================] - 285s 152ms/step - loss: 0.4320 - accuracy: 0.8448 - val_loss: 0.7774 - val_accuracy: 0.7828
# Epoch 9/25
# 1875/1875 [==============================] - 275s 147ms/step - loss: 0.3911 - accuracy: 0.8596 - val_loss: 0.7495 - val_accuracy: 0.8068
# Epoch 10/25
# 1875/1875 [==============================] - 277s 148ms/step - loss: 0.3773 - accuracy: 0.8624 - val_loss: 0.7948 - val_accuracy: 0.8092
# Epoch 11/25
# 1875/1875 [==============================] - 278s 148ms/step - loss: 0.3527 - accuracy: 0.8699 - val_loss: 1.1733 - val_accuracy: 0.7900
# Epoch 12/25
# 1875/1875 [==============================] - 278s 148ms/step - loss: 0.3661 - accuracy: 0.8667 - val_loss: 0.8114 - val_accuracy: 0.8212
# Epoch 13/25
# 1875/1875 [==============================] - 275s 147ms/step - loss: 0.3454 - accuracy: 0.8768 - val_loss: 1.0031 - val_accuracy: 0.8012
# Epoch 14/25
# 1875/1875 [==============================] - 277s 148ms/step - loss: 0.3174 - accuracy: 0.8771 - val_loss: 0.8511 - val_accuracy: 0.8304
# Epoch 15/25
# 1875/1875 [==============================] - 277s 148ms/step - loss: 0.3428 - accuracy: 0.8804 - val_loss: 0.9078 - val_accuracy: 0.8120
# Epoch 16/25
# 1875/1875 [==============================] - 275s 147ms/step - loss: 0.3259 - accuracy: 0.8856 - val_loss: 0.9878 - val_accuracy: 0.8124
# Epoch 17/25
# 1875/1875 [==============================] - 274s 146ms/step - loss: 0.2876 - accuracy: 0.8884 - val_loss: 0.8416 - val_accuracy: 0.8272
# Epoch 18/25
# 1875/1875 [==============================] - 272s 145ms/step - loss: 0.3052 - accuracy: 0.8868 - val_loss: 1.0037 - val_accuracy: 0.8328
# Epoch 19/25
# 1875/1875 [==============================] - 275s 147ms/step - loss: 0.2900 - accuracy: 0.8921 - val_loss: 0.9666 - val_accuracy: 0.8364
# Epoch 20/25
# 1875/1875 [==============================] - 272s 145ms/step - loss: 0.3040 - accuracy: 0.8925 - val_loss: 1.3429 - val_accuracy: 0.7996
# Epoch 21/25
# 1875/1875 [==============================] - 277s 148ms/step - loss: 0.3063 - accuracy: 0.8959 - val_loss: 1.1096 - val_accuracy: 0.8280
# Epoch 22/25
# 1875/1875 [==============================] - 275s 147ms/step - loss: 0.2640 - accuracy: 0.8992 - val_loss: 1.1958 - val_accuracy: 0.8152
# Epoch 23/25
# 1875/1875 [==============================] - 273s 146ms/step - loss: 0.3004 - accuracy: 0.8935 - val_loss: 1.4820 - val_accuracy: 0.8168
# Epoch 24/25
# 1875/1875 [==============================] - 274s 146ms/step - loss: 0.2887 - accuracy: 0.8995 - val_loss: 1.0874 - val_accuracy: 0.8260
# Epoch 25/25
# 1875/1875 [==============================] - 272s 145ms/step - loss: 0.2878 - accuracy: 0.8979 - val_loss: 1.2193 - val_accuracy: 0.8204

# %%
#
# Visualize image class probabilities 
#
def decode_label_prob(y, classes):
    labels = []
    for i ,c in enumerate(classes):
        labels.append(f'{c}: {y[i]:.2%}')
    return labels

n_col, n_row = 6, 3
f, ax = plt.subplots(n_row, n_col, figsize=(20, 25))
for i in range(n_row):
    for j in range(n_col):
        idx = n_col*i + j
        class_probs = transfer_model.predict(x_test[idx:idx+1])[0]
        ax[i, j].imshow(x_test[idx]/255)
        ax[i, j].set_axis_off()
        ax[i, j].set_title('\n'.join(decode_label_prob(class_probs, mlb.classes_)))
        
plt.tight_layout()

# %%
#
# Compute the embeddings for visualization
#
n_samples = 100
embedding_outputs = transfer_model.get_layer('embeddigns').output
embedding_model = Model([transfer_model.input], embedding_outputs)

images = x_test[0:n_samples]
image_embeddings = embedding_model.predict(images)
image_labels = decode_labels(y_test[0:n_samples], mlb)
print(image_embeddings.shape)
# Out:
# (100, 32)

# %%
#
# Visualize the 2D-projection of the embedding space with example images (thumbnails)
#
def embedding_plot(X, y_labels, images, mode = 'points', thumbnail_sparsity = 0.005, thumbnail_size = 0.25):
    x_min, x_max = np.min(X, axis=0), np.max(X, axis=0)
    X = (X - x_min) / (x_max - x_min)
    fig, ax = plt.subplots(1, figsize=(12, 12))
    
    if mode == 'points':
        uniq = list(set(y_labels))
        z = range(1, len(uniq))
        hot = plt.get_cmap('viridis')
        cNorm  = colors.Normalize(vmin=0, vmax=len(uniq))
        scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=hot)
    
        for i in range(len(uniq)):
            indx = np.argwhere(y_labels == uniq[i]).T
            ax.scatter(X[indx, 0], X[indx, 1], s=30, marker='o', 
                    color=scalarMap.to_rgba(i), label=uniq[i], alpha=0.5) 
        plt.legend(loc='upper left')

    if mode == 'thumbnails':
        shown_images = np.array([[1., 1.]])
        for i in range(X.shape[0]):
            if np.min(np.sum((X[i] - shown_images) ** 2, axis=1)) < thumbnail_sparsity: continue
            shown_images = np.r_[shown_images, [X[i]]]
            thumbnail = offsetbox.OffsetImage(images[i], cmap=plt.cm.gray_r, zoom=thumbnail_size)
            ax.add_artist(offsetbox.AnnotationBbox(thumbnail, X[i], bboxprops = dict(edgecolor='white'), pad=0.0))

    plt.grid(True)
    
tsne = manifold.TSNE(n_components=2, init='pca', perplexity=20, random_state=0)
X_tsne = tsne.fit_transform(image_embeddings)
embedding_plot(X_tsne, y_labels=image_labels, images=images/255, mode = 'thumbnails')

# %%
inputs = tensorflow.keras.layers.Input((10, 10, 1))
conv = tensorflow.keras.layers.Conv2DTranspose(1, kernel_size=(2, 2), strides=(2,2))(inputs)
model = Model(inputs=inputs, outputs=conv)
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 10, 10, 1)]       0
#
#  conv2d_transpose (Conv2DTra  (None, 20, 20, 1)        5
#  nspose)
#
# =================================================================
# Total params: 5
# Trainable params: 5
# Non-trainable params: 0
# _________________________________________________________________
